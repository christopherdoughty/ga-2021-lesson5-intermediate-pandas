# %% [markdown]
# <img align="left" style="padding-right: 5px" valign="center" src="https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png" width="28px">
#
# # Intermediate pandas

# %% [markdown]
# *By Joseph Nelson, Jeff Hale and unknown other GA folks*

# %% [markdown]
# ## Learning Objectives:
#
# After this lesson, students will be able to:
# - Use the `groupby` method to aggregate data by group
# - Use `replace`, `value_counts`, `unique`, `nunique`, and `sample` on a DataFrame
# - Combine DataFrames with `concat`
# - Do joins with `merge`

# %% [markdown]
# #### Prior knowledge required:
#
# - Python basics
# - Pandas basics

# %% [markdown]
# Pandas Documentation on [Merging data](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html)

# %% [markdown]
# <div id="import"></div>
# <h2>Import Pandas</h2>

# %%
import pandas as pd
import numpy as np
print(f'Pandas v{pd.__version__}\n Numpy v{np.__version__}')
# Out:
# Pandas v1.2.4
#  Numpy v1.20.1

# %% [markdown]
# ---
# # Split-Apply-Combine with `groupby`
#
# What if we want summary statistics _with respect to some categorical variable?_
#
# For example, the price of a diamond probably varies widely between different diamond cuts. To tackle this problem, we'll use the **Split-Apply-Combine** technique.
#
# * **Split**: Separate your data into different DataFrames, one for each category.
# * **Apply**: On each split-up DataFrame, apply some function or transformation (for example, the mean).
# * **Combine**: Take the results and combine the split-up DataFrames back into one aggregate DataFrame.

# %% [markdown]
# #### **Slack**: Import the Airbnb dataset

# %%
airbnb = pd.read_csv("./data/airbnb_listings.csv")

# %%
airbnb.head(2)
# Out:
#      id                                               name  host_id host_name  \
# 0  2265   Zen-East in the Heart of Austin (monthly rental)     2466     Paddy
# 1  5245  Eco friendly, Colorful, Clean, Cozy monthly share     2466     Paddy
#
#    neighbourhood_group  neighbourhood  latitude  longitude        room_type  \
# 0                  NaN          78702  30.27752  -97.71377  Entire home/apt
# 1                  NaN          78702  30.27614  -97.71320     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    200               7                 26  2021-07-02               0.38
# 1    114              30                  9  2017-02-24               0.22
#
#    calculated_host_listings_count  availability_365
# 0                               3                51
# 1                               3                 0

# %% [markdown]
# #### Inspect

# %%
airbnb.describe()
# Out:
#                  id       host_id  neighbourhood_group  neighbourhood  \
# count  1.035000e+04  1.035000e+04                  0.0   10350.000000
# mean   2.836757e+07  9.792277e+07                  NaN   78723.159420
# std    1.608979e+07  1.118991e+08                  NaN      20.805698
# min    2.265000e+03  2.300000e+01                  NaN   78701.000000
# 25%    1.504138e+07  1.170741e+07                  NaN   78704.000000
# 50%    2.888472e+07  4.744496e+07                  NaN   78722.000000
# 75%    4.351866e+07  1.498711e+08                  NaN   78745.000000
# max    5.090360e+07  4.110306e+08                  NaN   78759.000000
#
#            latitude     longitude         price  minimum_nights  \
# count  10350.000000  10350.000000  10350.000000    10350.000000
# mean      30.279833    -97.752227    277.324831        7.714396
# std        0.059749      0.059600    546.320050       24.376424
# min       30.078870    -98.056630      0.000000        1.000000
# 25%       30.244343    -97.769207     90.000000        1.000000
# 50%       30.269655    -97.744630    150.000000        2.000000
# 75%       30.302877    -97.720460    275.000000        3.000000
# max       30.515090    -97.560620  16845.000000     1100.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       10350.000000        7944.000000                    10350.000000
# mean           32.915652           2.485487                       10.415652
# std            69.867453           6.855260                       27.583589
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.190000                        1.000000
# 50%             6.000000           0.900000                        1.000000
# 75%            30.000000           2.510000                        4.000000
# max           917.000000         250.000000                      158.000000
#
#        availability_365
# count      10350.000000
# mean         116.768889
# std          130.627737
# min            0.000000
# 25%            0.000000
# 50%           64.000000
# 75%          233.000000
# max          365.000000

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10350 entries, 0 to 10349
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              10350 non-null  int64
#  1   name                            10350 non-null  object
#  2   host_id                         10350 non-null  int64
#  3   host_name                       10334 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   10350 non-null  int64
#  6   latitude                        10350 non-null  float64
#  7   longitude                       10350 non-null  float64
#  8   room_type                       10350 non-null  object
#  9   price                           10350 non-null  int64
#  10  minimum_nights                  10350 non-null  int64
#  11  number_of_reviews               10350 non-null  int64
#  12  last_review                     7944 non-null   object
#  13  reviews_per_month               7944 non-null   float64
#  14  calculated_host_listings_count  10350 non-null  int64
#  15  availability_365                10350 non-null  int64
# dtypes: float64(4), int64(8), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# #### What is the mean price by room type?

# %%
airbnb['room_type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
airbnb['room_type'].value_counts()
# Out:
# Entire home/apt    8168
# Private room       2050
# Shared room         121
# Hotel room           11
# Name: room_type, dtype: int64

# %%
airbnb.groupby('room_type').mean()
# Out:
#                            id       host_id  neighbourhood_group  \
# room_type
# Entire home/apt  2.900129e+07  9.900012e+07                  NaN
# Hotel room       2.891924e+07  1.212280e+08                  NaN
# Private room     2.605988e+07  9.536797e+07                  NaN
# Shared room      2.463590e+07  6.636223e+07                  NaN
#
#                  neighbourhood   latitude  longitude       price  \
# room_type
# Entire home/apt   78721.379163  30.278627 -97.754818  318.310847
# Hotel room        78715.363636  30.288099 -97.787508  579.727273
# Private room      78729.594146  30.283663 -97.742918  124.733171
# Shared room       78735.024793  30.295572 -97.731860   68.338843
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt        7.969148          36.388222           2.778648
# Hotel room             2.000000          13.909091           0.653333
# Private room           6.378049          20.702439           1.366372
# Shared room           13.677686           7.148760           0.537609
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       11.768242        124.395813
# Hotel room                             3.545455        116.454545
# Private room                           3.902439         84.343415
# Shared room                           30.082645        151.305785

# %%
airbnb.groupby('room_type')['price'].mean()
# Out:
# room_type
# Entire home/apt    318.310847
# Hotel room         579.727273
# Private room       124.733171
# Shared room         68.338843
# Name: price, dtype: float64

# %%
airbnb.groupby('room_type')[['price' , 'number_of_reviews']].mean()
# Out:
#                       price  number_of_reviews
# room_type
# Entire home/apt  318.310847          36.388222
# Hotel room       579.727273          13.909091
# Private room     124.733171          20.702439
# Shared room       68.338843           7.148760

# %% [markdown]
# #### Sort the results

# %%
airbnb.groupby('room_type')['price'].mean().sort_values()
# Out:
# room_type
# Shared room         68.338843
# Private room       124.733171
# Entire home/apt    318.310847
# Hotel room         579.727273
# Name: price, dtype: float64

# %%
airbnb.groupby('room_type')['price'].mean().sort_values(ascending = False)
# Out:
# room_type
# Hotel room         579.727273
# Entire home/apt    318.310847
# Private room       124.733171
# Shared room         68.338843
# Name: price, dtype: float64

# %%
airbnb.groupby('room_type').mean().sort_values(by = 'price', ascending = False)
# Out:
#                            id       host_id  neighbourhood_group  \
# room_type
# Hotel room       2.891924e+07  1.212280e+08                  NaN
# Entire home/apt  2.900129e+07  9.900012e+07                  NaN
# Private room     2.605988e+07  9.536797e+07                  NaN
# Shared room      2.463590e+07  6.636223e+07                  NaN
#
#                  neighbourhood   latitude  longitude       price  \
# room_type
# Hotel room        78715.363636  30.288099 -97.787508  579.727273
# Entire home/apt   78721.379163  30.278627 -97.754818  318.310847
# Private room      78729.594146  30.283663 -97.742918  124.733171
# Shared room       78735.024793  30.295572 -97.731860   68.338843
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Hotel room             2.000000          13.909091           0.653333
# Entire home/apt        7.969148          36.388222           2.778648
# Private room           6.378049          20.702439           1.366372
# Shared room           13.677686           7.148760           0.537609
#
#                  calculated_host_listings_count  availability_365
# room_type
# Hotel room                             3.545455        116.454545
# Entire home/apt                       11.768242        124.395813
# Private room                           3.902439         84.343415
# Shared room                           30.082645        151.305785

# %% [markdown]
# #### Using the `.agg` method

# %%
airbnb.groupby('room_type').agg(np.mean)
# Out:
#                            id       host_id  neighbourhood_group  \
# room_type
# Entire home/apt  2.900129e+07  9.900012e+07                  NaN
# Hotel room       2.891924e+07  1.212280e+08                  NaN
# Private room     2.605988e+07  9.536797e+07                  NaN
# Shared room      2.463590e+07  6.636223e+07                  NaN
#
#                  neighbourhood   latitude  longitude       price  \
# room_type
# Entire home/apt   78721.379163  30.278627 -97.754818  318.310847
# Hotel room        78715.363636  30.288099 -97.787508  579.727273
# Private room      78729.594146  30.283663 -97.742918  124.733171
# Shared room       78735.024793  30.295572 -97.731860   68.338843
#
#                  minimum_nights  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt        7.969148          36.388222           2.778648
# Hotel room             2.000000          13.909091           0.653333
# Private room           6.378049          20.702439           1.366372
# Shared room           13.677686           7.148760           0.537609
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                       11.768242        124.395813
# Hotel room                             3.545455        116.454545
# Private room                           3.902439         84.343415
# Shared room                           30.082645        151.305785

# %%
airbnb.groupby('room_type')[['price', 'number_of_reviews']].agg(np.mean)
# Out:
#                       price  number_of_reviews
# room_type
# Entire home/apt  318.310847          36.388222
# Hotel room       579.727273          13.909091
# Private room     124.733171          20.702439
# Shared room       68.338843           7.148760

# %%
airbnb.groupby('room_type')[['price', 'number_of_reviews']].agg([np.mean, np.median])
# Out:
#                       price        number_of_reviews
#                        mean median              mean median
# room_type
# Entire home/apt  318.310847    175         36.388222      7
# Hotel room       579.727273    210         13.909091      1
# Private room     124.733171     65         20.702439      3
# Shared room       68.338843     28          7.148760      3

# %%
airbnb_aggs = airbnb.groupby('room_type')[['price', 'number_of_reviews']].agg([np.mean, np.median])

# %%
room_stats = airbnb.groupby('room_type').agg([np.mean, np.median])

# %%
room_stats.head(2)
# Out:
#                            id                 host_id            \
#                          mean    median          mean    median
# room_type
# Entire home/apt  2.900129e+07  30337209  9.900012e+07  46485292
# Hotel room       2.891924e+07  32171574  1.212280e+08  77021411
#
#                 neighbourhood_group        neighbourhood            latitude  \
#                                mean median          mean   median       mean
# room_type
# Entire home/apt                 NaN    NaN  78721.379163  78705.0  30.278627
# Hotel room                      NaN    NaN  78715.363636  78701.0  30.288099
#
#                            ... minimum_nights        number_of_reviews         \
#                    median  ...           mean median              mean median
# room_type                  ...
# Entire home/apt  30.26829  ...       7.969148      2         36.388222      7
# Hotel room       30.27191  ...       2.000000      2         13.909091      1
#
#                 reviews_per_month        calculated_host_listings_count  \
#                              mean median                           mean
# room_type
# Entire home/apt          2.778648  1.035                      11.768242
# Hotel room               0.653333  0.060                       3.545455
#
#                        availability_365
#                 median             mean median
# room_type
# Entire home/apt      1       124.395813     77
# Hotel room           3       116.454545      0
#
# [2 rows x 24 columns]

# %%
room_stats['minimum_nights']['mean']
# Out:
# room_type
# Entire home/apt     7.969148
# Hotel room          2.000000
# Private room        6.378049
# Shared room        13.677686
# Name: mean, dtype: float64

# %% [markdown]
# #### Now you have a multi-index column. In general, I suggest you avoid hierarchical indexes whenever possible - they can be tricky. How would you figure out how to flatten a multi-index?

# %%
df.columns = df.columns.get_level_values(0)
Link: https://stackoverflow.com/questions/14507794/pandas-how-to-flatten-a-hierarchical-index-in-columns

# %%
room_stats.columns = room_stats.columns.get_level_values(0)

# %%
room_stats.columns = room_stats.columns.map('_'.join)

# %%
room_stats
# Out:
#                       id_mean  id_median  host_id_mean  host_id_median  \
# room_type
# Entire home/apt  2.900129e+07   30337209  9.900012e+07        46485292
# Hotel room       2.891924e+07   32171574  1.212280e+08        77021411
# Private room     2.605988e+07   23715203  9.536797e+07        51358009
# Shared room      2.463590e+07   21881807  6.636223e+07        20523885
#
#                  neighbourhood_group_mean  neighbourhood_group_median  \
# room_type
# Entire home/apt                       NaN                         NaN
# Hotel room                            NaN                         NaN
# Private room                          NaN                         NaN
# Shared room                           NaN                         NaN
#
#                  neighbourhood_mean  neighbourhood_median  latitude_mean  \
# room_type
# Entire home/apt        78721.379163               78705.0      30.278627
# Hotel room             78715.363636               78701.0      30.288099
# Private room           78729.594146               78733.5      30.283663
# Shared room            78735.024793               78746.0      30.295572
#
#                  latitude_median  ...  minimum_nights_mean  \
# room_type                         ...
# Entire home/apt         30.26829  ...             7.969148
# Hotel room              30.27191  ...             2.000000
# Private room            30.27330  ...             6.378049
# Shared room             30.30390  ...            13.677686
#
#                  minimum_nights_median  number_of_reviews_mean  \
# room_type
# Entire home/apt                      2               36.388222
# Hotel room                           2               13.909091
# Private room                         1               20.702439
# Shared room                          2                7.148760
#
#                  number_of_reviews_median  reviews_per_month_mean  \
# room_type
# Entire home/apt                         7                2.778648
# Hotel room                              1                0.653333
# Private room                            3                1.366372
# Shared room                             3                0.537609
#
#                  reviews_per_month_median  \
# room_type
# Entire home/apt                     1.035
# Hotel room                          0.060
# Private room                        0.380
# Shared room                         0.140
#
#                  calculated_host_listings_count_mean  \
# room_type
# Entire home/apt                            11.768242
# Hotel room                                  3.545455
# Private room                                3.902439
# Shared room                                30.082645
#
#                  calculated_host_listings_count_median  availability_365_mean  \
# room_type
# Entire home/apt                                      1             124.395813
# Hotel room                                           3             116.454545
# Private room                                         1              84.343415
# Shared room                                          3             151.305785
#
#                  availability_365_median
# room_type
# Entire home/apt                       77
# Hotel room                             0
# Private room                           0
# Shared room                           90
#
# [4 rows x 24 columns]

# %%
Link: https://stackoverflow.com/questions/50571793/concise-way-of-flattening-multiindex-columns

# %%
room_stats.columns = ['_'.join(col) for col in room_stats.columns.values]

# %%
room_stats
# Out:
#                            id                 host_id            \
#                          mean    median          mean    median
# room_type
# Entire home/apt  2.900129e+07  30337209  9.900012e+07  46485292
# Hotel room       2.891924e+07  32171574  1.212280e+08  77021411
# Private room     2.605988e+07  23715203  9.536797e+07  51358009
# Shared room      2.463590e+07  21881807  6.636223e+07  20523885
#
#                 neighbourhood_group        neighbourhood            latitude  \
#                                mean median          mean   median       mean
# room_type
# Entire home/apt                 NaN    NaN  78721.379163  78705.0  30.278627
# Hotel room                      NaN    NaN  78715.363636  78701.0  30.288099
# Private room                    NaN    NaN  78729.594146  78733.5  30.283663
# Shared room                     NaN    NaN  78735.024793  78746.0  30.295572
#
#                            ... minimum_nights        number_of_reviews         \
#                    median  ...           mean median              mean median
# room_type                  ...
# Entire home/apt  30.26829  ...       7.969148      2         36.388222      7
# Hotel room       30.27191  ...       2.000000      2         13.909091      1
# Private room     30.27330  ...       6.378049      1         20.702439      3
# Shared room      30.30390  ...      13.677686      2          7.148760      3
#
#                 reviews_per_month        calculated_host_listings_count  \
#                              mean median                           mean
# room_type
# Entire home/apt          2.778648  1.035                      11.768242
# Hotel room               0.653333  0.060                       3.545455
# Private room             1.366372  0.380                       3.902439
# Shared room              0.537609  0.140                      30.082645
#
#                        availability_365
#                 median             mean median
# room_type
# Entire home/apt      1       124.395813     77
# Hotel room           3       116.454545      0
# Private room         1        84.343415      0
# Shared room          3       151.305785     90
#
# [4 rows x 24 columns]

# %%
room_stats.columns = ["_".join(a) for a in room_stats.columns.to_flat_index()]

# %%
room_stats
# Out:
#                       id_mean  id_median  host_id_mean  host_id_median  \
# room_type
# Entire home/apt  2.900129e+07   30337209  9.900012e+07        46485292
# Hotel room       2.891924e+07   32171574  1.212280e+08        77021411
# Private room     2.605988e+07   23715203  9.536797e+07        51358009
# Shared room      2.463590e+07   21881807  6.636223e+07        20523885
#
#                  neighbourhood_group_mean  neighbourhood_group_median  \
# room_type
# Entire home/apt                       NaN                         NaN
# Hotel room                            NaN                         NaN
# Private room                          NaN                         NaN
# Shared room                           NaN                         NaN
#
#                  neighbourhood_mean  neighbourhood_median  latitude_mean  \
# room_type
# Entire home/apt        78721.379163               78705.0      30.278627
# Hotel room             78715.363636               78701.0      30.288099
# Private room           78729.594146               78733.5      30.283663
# Shared room            78735.024793               78746.0      30.295572
#
#                  latitude_median  ...  minimum_nights_mean  \
# room_type                         ...
# Entire home/apt         30.26829  ...             7.969148
# Hotel room              30.27191  ...             2.000000
# Private room            30.27330  ...             6.378049
# Shared room             30.30390  ...            13.677686
#
#                  minimum_nights_median  number_of_reviews_mean  \
# room_type
# Entire home/apt                      2               36.388222
# Hotel room                           2               13.909091
# Private room                         1               20.702439
# Shared room                          2                7.148760
#
#                  number_of_reviews_median  reviews_per_month_mean  \
# room_type
# Entire home/apt                         7                2.778648
# Hotel room                              1                0.653333
# Private room                            3                1.366372
# Shared room                             3                0.537609
#
#                  reviews_per_month_median  \
# room_type
# Entire home/apt                     1.035
# Hotel room                          0.060
# Private room                        0.380
# Shared room                         0.140
#
#                  calculated_host_listings_count_mean  \
# room_type
# Entire home/apt                            11.768242
# Hotel room                                  3.545455
# Private room                                3.902439
# Shared room                                30.082645
#
#                  calculated_host_listings_count_median  availability_365_mean  \
# room_type
# Entire home/apt                                      1             124.395813
# Hotel room                                           3             116.454545
# Private room                                         1              84.343415
# Shared room                                          3             151.305785
#
#                  availability_365_median
# room_type
# Entire home/apt                       77
# Hotel room                             0
# Private room                           0
# Shared room                           90
#
# [4 rows x 24 columns]

# %%
room_stats.columns = ["_".join(a) for a in room_stats.columns]

# %%
room_stats
# Out:
#                       id_mean  id_median  host_id_mean  host_id_median  \
# room_type
# Entire home/apt  2.900129e+07   30337209  9.900012e+07        46485292
# Hotel room       2.891924e+07   32171574  1.212280e+08        77021411
# Private room     2.605988e+07   23715203  9.536797e+07        51358009
# Shared room      2.463590e+07   21881807  6.636223e+07        20523885
#
#                  neighbourhood_group_mean  neighbourhood_group_median  \
# room_type
# Entire home/apt                       NaN                         NaN
# Hotel room                            NaN                         NaN
# Private room                          NaN                         NaN
# Shared room                           NaN                         NaN
#
#                  neighbourhood_mean  neighbourhood_median  latitude_mean  \
# room_type
# Entire home/apt        78721.379163               78705.0      30.278627
# Hotel room             78715.363636               78701.0      30.288099
# Private room           78729.594146               78733.5      30.283663
# Shared room            78735.024793               78746.0      30.295572
#
#                  latitude_median  ...  minimum_nights_mean  \
# room_type                         ...
# Entire home/apt         30.26829  ...             7.969148
# Hotel room              30.27191  ...             2.000000
# Private room            30.27330  ...             6.378049
# Shared room             30.30390  ...            13.677686
#
#                  minimum_nights_median  number_of_reviews_mean  \
# room_type
# Entire home/apt                      2               36.388222
# Hotel room                           2               13.909091
# Private room                         1               20.702439
# Shared room                          2                7.148760
#
#                  number_of_reviews_median  reviews_per_month_mean  \
# room_type
# Entire home/apt                         7                2.778648
# Hotel room                              1                0.653333
# Private room                            3                1.366372
# Shared room                             3                0.537609
#
#                  reviews_per_month_median  \
# room_type
# Entire home/apt                     1.035
# Hotel room                          0.060
# Private room                        0.380
# Shared room                         0.140
#
#                  calculated_host_listings_count_mean  \
# room_type
# Entire home/apt                            11.768242
# Hotel room                                  3.545455
# Private room                                3.902439
# Shared room                                30.082645
#
#                  calculated_host_listings_count_median  availability_365_mean  \
# room_type
# Entire home/apt                                      1             124.395813
# Hotel room                                           3             116.454545
# Private room                                         1              84.343415
# Shared room                                          3             151.305785
#
#                  availability_365_median
# room_type
# Entire home/apt                       77
# Hotel room                             0
# Private room                           0
# Shared room                           90
#
# [4 rows x 24 columns]

# %% [markdown]
# #### How do you groupby `room_type` and `neighborhood`?

# %%
airbnb.groupby(['room_type', 'neighbourhood']).median()
# Out:
#                                        id      host_id  neighbourhood_group  \
# room_type       neighbourhood
# Entire home/apt 78701          38070578.0   74292291.0                  NaN
#                 78702          28962698.5   26440310.5                  NaN
#                 78703          22172050.0   28648585.0                  NaN
#                 78704          23319078.0   28767982.0                  NaN
#                 78705          29240059.0   88566861.0                  NaN
# ...                                   ...          ...                  ...
# Shared room     78752          32839654.0   20484642.0                  NaN
#                 78753          37048493.0  125839353.0                  NaN
#                 78756          27547539.0    8167447.0                  NaN
#                 78757          33476154.5  104826449.0                  NaN
#                 78758          37173968.5  200360713.0                  NaN
#
#                                 latitude  longitude  price  minimum_nights  \
# room_type       neighbourhood
# Entire home/apt 78701          30.271075 -97.747035  240.0             2.0
#                 78702          30.262225 -97.720410  198.0             2.0
#                 78703          30.280970 -97.760010  210.0             2.0
#                 78704          30.246710 -97.760810  182.0             2.0
#                 78705          30.291005 -97.744305  150.0             2.0
# ...                                  ...        ...    ...             ...
# Shared room     78752          30.329450 -97.699750  100.0             1.0
#                 78753          30.390700 -97.647480   15.0             1.0
#                 78756          30.319970 -97.730960   17.0            30.0
#                 78757          30.355650 -97.728485   35.0            15.5
#                 78758          30.371275 -97.712495  164.0             2.0
#
#                                number_of_reviews  reviews_per_month  \
# room_type       neighbourhood
# Entire home/apt 78701                        2.0              0.590
#                 78702                       15.0              1.500
#                 78703                        5.0              0.840
#                 78704                        8.0              0.910
#                 78705                        6.0              1.110
# ...                                          ...                ...
# Shared room     78752                        0.0                NaN
#                 78753                        5.0              0.240
#                 78756                        4.0              0.135
#                 78757                        0.0                NaN
#                 78758                        0.0                NaN
#
#                                calculated_host_listings_count  \
# room_type       neighbourhood
# Entire home/apt 78701                                     4.5
#                 78702                                     1.0
#                 78703                                     1.0
#                 78704                                     1.0
#                 78705                                     1.0
# ...                                                       ...
# Shared room     78752                                     1.0
#                 78753                                     1.0
#                 78756                                    76.0
#                 78757                                     1.0
#                 78758                                     1.0
#
#                                availability_365
# room_type       neighbourhood
# Entire home/apt 78701                      48.0
#                 78702                      75.0
#                 78703                      77.0
#                 78704                      70.0
#                 78705                      19.0
# ...                                         ...
# Shared room     78752                     179.0
#                 78753                       0.0
#                 78756                     339.0
#                 78757                      89.5
#                 78758                      45.0
#
# [120 rows x 11 columns]

# %%
airbnb.groupby(['room_type', 'neighbourhood'])['price'].median()
# Out:
# room_type        neighbourhood
# Entire home/apt  78701            240.0
#                  78702            198.0
#                  78703            210.0
#                  78704            182.0
#                  78705            150.0
#                                   ...
# Shared room      78752            100.0
#                  78753             15.0
#                  78756             17.0
#                  78757             35.0
#                  78758            164.0
# Name: price, Length: 120, dtype: float64

# %% [markdown]
# ___
# ## Exercises

# %% [markdown]
# #### Sort the airbnb DataFrame by most expensive to least expensive listing

# %%
airbnb.sort_values(by = 'price', ascending = False)
# Out:
#             id                                               name    host_id  \
# 8298  46081394  ABOVE PREMIERE I LAKEFRONT I INDOOR/OUTDOOR PO...  210733801
# 6344  36868625                            Sapphire on Lake Austin  210733801
# 7436  42351709            WanderJaunt | Carolyn | 2BR | Hyde Park  104309976
# 4151  23003072  Amazing Luxury in Downtown Austin perfect for ...     384732
# 920    4538217                                     The Cathédrale   22773046
# ...        ...                                                ...        ...
# 3417  19840835                        Eco Friendly Tiny Apartment    3440175
# 3577  20674436                       Hurricane Harvey Refuge ONLY    3594051
# 3593  20708014                     small room for Harvey evacuees   22987908
# 8254  45895289                                Hotel Saint Cecilia  260188286
# 7590  42738847                              Hotel Granduca Austin  314291208
#
#                 host_name  neighbourhood_group  neighbourhood   latitude  \
# 8298       Above Vacation                  NaN          78733  30.343100
# 6344       Above Vacation                  NaN          78733  30.336170
# 7436          WanderJaunt                  NaN          78751  30.304020
# 4151               Andres                  NaN          78701  30.268090
# 920                   Eli                  NaN          78723  30.317060
# ...                   ...                  ...            ...        ...
# 3417                James                  NaN          78702  30.254380
# 3577              Michael                  NaN          78704  30.239280
# 3593            Elizabeth                  NaN          78757  30.355100
# 8254  Hotel Saint Cecilia                  NaN          78704  30.251623
# 7590       Hotel Granduca                  NaN          78746  30.301810
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 8298 -97.878650  Entire home/apt  16845               1                  0
# 6344 -97.847720  Entire home/apt  14739               1                  0
# 7436 -97.725380  Entire home/apt  10000               1                 20
# 4151 -97.749710  Entire home/apt  10000             500                  1
# 920  -97.683100  Entire home/apt  10000              30                  3
# ...         ...              ...    ...             ...                ...
# 3417 -97.703060     Private room      5               1                  1
# 3577 -97.742980  Entire home/apt      1               2                  2
# 3593 -97.738090     Private room      1               1                  0
# 8254 -97.746515       Hotel room      0               1                  0
# 7590 -97.829100       Hotel room      0               1                  0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 8298         NaN                NaN                              41
# 6344         NaN                NaN                              41
# 7436  2021-06-20               1.22                             142
# 4151  2018-03-14               0.02                               1
# 920   2015-05-23               0.04                               1
# ...          ...                ...                             ...
# 3417  2017-07-16               0.02                               8
# 3577  2017-09-10               0.04                               1
# 3593         NaN                NaN                               1
# 8254         NaN                NaN                               1
# 7590         NaN                NaN                               1
#
#       availability_365
# 8298               360
# 6344               355
# 7436                 0
# 4151               180
# 920                  0
# ...                ...
# 3417                 0
# 3577                 0
# 3593                 0
# 8254                 0
# 7590                 0
#
# [10350 rows x 16 columns]

# %% [markdown]
# #### Show the max listing price for each neighbourhood

# %%
airbnb.groupby('neighbourhood')['price'].max().sort_values(ascending = False)
# Out:
# neighbourhood
# 78733    16845
# 78701    10000
# 78723    10000
# 78751    10000
# 78702    10000
# 78750     9998
# 78703     9718
# 78746     6948
# 78704     6316
# 78732     6159
# 78730     5474
# 78749     5021
# 78734     5000
# 78741     4999
# 78738     3696
# 78737     3073
# 78731     3000
# 78756     3000
# 78735     3000
# 78745     2500
# 78705     2450
# 78722     2000
# 78736     1880
# 78752     1764
# 78721     1665
# 78728     1499
# 78759     1250
# 78725     1200
# 78748     1157
# 78739     1099
# 78724     1050
# 78742     1000
# 78757     1000
# 78754     1000
# 78729     1000
# 78744      950
# 78753      900
# 78726      825
# 78717      700
# 78747      607
# 78727      574
# 78758      557
# 78712      500
# 78719      171
# Name: price, dtype: int64

# %%
airbnb.groupby(['neighbourhood']).agg([np.max])
# Out:
#                      id                                               name  \
#                    amax                                               amax
# neighbourhood
# 78701          50790623    🏙 Modern Hip 1 BR High Rise Condo Pool Gameroom
# 78702          50896809  🥂Rainey Street—6 min walk ♫ 6th Street—3 min d...
# 78703          50896316  ★The ATX Oasis★  FUN, 3 story house w/ pool & ...
# 78704          50901766  🏯 LIMITED DISCOUNT Cozy Oriental Extended Stay...
# 78705          50903601    ★Only Airbnb in Austin w/ 5 desks★   WFH Ready!
# 78712          10764579                                                Zat
# 78717          50815145                                         true peace
# 78719          43874171                    The Sea Shell vintage tiny home
# 78721          50808276   ⚡️Large Duplex, Eastside Gem 💎 2 Masters suites!
# 78722          50873115         WanderJaunt | Valencia | 1BR | East Austin
# 78723          50726704    ✿ Enchanting Lavender Wisteria Garden ✿ DT East
# 78724          50772497      ⭐Tesla Giga Retreat⭐3 bd, 2.5 bth⭐2 King Beds
# 78725          50776317                          ✨PRIVATE 1st Floor Suite✨
# 78726          50507761  Wow-5 BRs, Deck,Grill, Firepit, Near Lakes, Do...
# 78727          50857382   ⭐️North Austin—Big Yard—Full Kitchen—Home office
# 78728          50797328  Wells Branch Home Backing to Mills Pond Greenbelt
# 78729          50899637  ☞ Budget Friendly Apt | Exterior 👎 Interior 👍 ...
# 78730          50778509                     Wild Basin Preserve Hills View
# 78731          50848534      ✪ Rare | Pool, Prime Location, Near Downtown!
# 78732          50813553            west room · Spacious Room, Lake Travis!
# 78733          49533399  Three-Story Timber Ridge Treehouse | Professio...
# 78734          50816679  🌊☀️🛶🌈Lake View /Lake Travis/Austin/ 1B1B @The ...
# 78735          50894161    Zen Apartment in the tree tops in south Austin.
# 78736          50031424           Zoo Stay: Your Unique Austin Opportunity
# 78737          50639655  ★The Hideaway★Heated Pool&Spa★Professional Clean★
# 78738          50868387           Your Own Private Hill Country Resort!!!!
# 78739          50723187  “Country in the City”  New Large Charming Cottage
# 78741          50893720  🚨Limited Weekly Discount | King Bed | Gym, Poo...
# 78742          50853896            chic house for two, 4 miles to Downtown
# 78744          50892412  🌿Peaceful Light-filled Bungalow in Backyard Oa...
# 78745          50899252   💻Google-Fiber & 5 mins to S Lamar/SoCo, 15 to DT
# 78746          50868339             painter’s one bedroom with wooded view
# 78747          50815390   entire apartment in south Austin **disscounted**
# 78748          50550217                        ★Capital of Texas - Luxury★
# 78749          50525313        Two Rooms w/ Private Bath, Very Comfortable
# 78750          50306562                     Trees, Trails and NW Austin...
# 78751          50853843      ✵Rare find✵Newly Remodeled Hyde Park bungalow
# 78752          50642966      ♡Central Austin- 3bed 2bath house - sleep 6+♡
# 78753          50870612            Work From Home/Private Room/Shared Bath
# 78754          50891958                                You're welcome home
# 78756          50850339                        spacious two story townhome
# 78757          50827862               ♥ of Austin Luxury Private bedroom ♥
# 78758          50867288  ⭐️Luxe Asian Retreat in the Domain | Gym, Pool...
# 78759          50809842                                    𝐓𝐡𝐞 𝐒𝐦𝐚𝐫𝐭 𝐂𝐨𝐧𝐝𝐨
#
#                  host_id neighbourhood_group  latitude  longitude  \
#                     amax                amax      amax       amax
# neighbourhood
# 78701          410019817                 NaN  30.28322 -97.734110
# 78702          410169720                 NaN  30.28209 -97.692880
# 78703          404924711                 NaN  30.31267 -97.750110
# 78704          411030626                 NaN  30.26606 -97.735560
# 78705          383824821                 NaN  30.30300 -97.721100
# 78712           27903197                 NaN  30.28664 -97.733980
# 78717          400522896                 NaN  30.51509 -97.722070
# 78719          254119744                 NaN  30.17627 -97.642740
# 78721          387977994                 NaN  30.28564 -97.674320
# 78722          372185009                 NaN  30.30429 -97.704940
# 78723          404049518                 NaN  30.32347 -97.663460
# 78724          400963006                 NaN  30.31430 -97.573160
# 78725          410124990                 NaN  30.28125 -97.560620
# 78726          220643373                 NaN  30.44262 -97.826780
# 78727          407539806                 NaN  30.44215 -97.679220
# 78728          373264154                 NaN  30.47757 -97.667471
# 78729          399364759                 NaN  30.47191 -97.747350
# 78730          372179504                 NaN  30.39018 -97.794750
# 78731          399520592                 NaN  30.38219 -97.745830
# 78732          346782298                 NaN  30.43056 -97.869140
# 78733          368049075                 NaN  30.35439 -97.841630
# 78734          407686704                 NaN  30.43167 -97.911780
# 78735          359036978                 NaN  30.29129 -97.804470
# 78736          376301532                 NaN  30.28504 -97.878240
# 78737          395921041                 NaN  30.24053 -97.893940
# 78738          398934409                 NaN  30.35673 -97.917050
# 78739          332781686                 NaN  30.20904 -97.850960
# 78741          408209953                 NaN  30.24884 -97.688220
# 78742          340173531                 NaN  30.24196 -97.660270
# 78744          398918753                 NaN  30.21102 -97.691890
# 78745          401070193                 NaN  30.23009 -97.760910
# 78746          368944610                 NaN  30.34694 -97.764810
# 78747          406197997                 NaN  30.16478 -97.714540
# 78748          400888114                 NaN  30.18933 -97.787420
# 78749          359339916                 NaN  30.23468 -97.823270
# 78750          406217149                 NaN  30.46467 -97.772930
# 78751          407531103                 NaN  30.32471 -97.708890
# 78752          406989219                 NaN  30.34274 -97.680030
# 78753          410540510                 NaN  30.42563 -97.646250
# 78754          410942702                 NaN  30.40297 -97.608800
# 78756          359036978                 NaN  30.33321 -97.727850
# 78757          408940286                 NaN  30.37487 -97.713830
# 78758          403138125                 NaN  30.41715 -97.680830
# 78759          390321341                 NaN  30.43297 -97.713010
#
#                   room_type  price minimum_nights number_of_reviews  \
#                        amax   amax           amax              amax
# neighbourhood
# 78701           Shared room  10000            500               819
# 78702           Shared room  10000            180               763
# 78703           Shared room   9718            999               509
# 78704           Shared room   6316            365               903
# 78705           Shared room   2450            365               632
# 78712          Private room    500              1                 0
# 78717          Private room    700            183               240
# 78719          Private room    171              3               113
# 78721           Shared room   1665            100               349
# 78722           Shared room   2000             70               361
# 78723           Shared room  10000            180               917
# 78724           Shared room   1050             45               135
# 78725           Shared room   1200             30               542
# 78726          Private room    825             28                40
# 78727           Shared room    574            120               275
# 78728           Shared room   1499             90               202
# 78729           Shared room   1000            120               280
# 78730          Private room   5474             90               200
# 78731           Shared room   3000            150               603
# 78732          Private room   6159             90               284
# 78733          Private room  16845             30               263
# 78734          Private room   5000            180               358
# 78735          Private room   3000             90                93
# 78736          Private room   1880             30               229
# 78737          Private room   3073             30               293
# 78738          Private room   3696            180               178
# 78739          Private room   1099             30               133
# 78741           Shared room   4999            360               320
# 78742          Private room   1000              3                66
# 78744           Shared room    950            180               648
# 78745           Shared room   2500            150               278
# 78746           Shared room   6948             31               269
# 78747           Shared room    607            180                86
# 78748           Shared room   1157             31               417
# 78749           Shared room   5021            180               445
# 78750           Shared room   9998            120               138
# 78751           Shared room  10000            175               499
# 78752           Shared room   1764           1100               325
# 78753           Shared room    900             90               250
# 78754          Private room   1000            365               289
# 78756           Shared room   3000             90               443
# 78757           Shared room   1000             90               366
# 78758           Shared room    557            300               559
# 78759          Private room   1250            150               299
#
#               reviews_per_month calculated_host_listings_count  \
#                            amax                           amax
# neighbourhood
# 78701                    150.00                            142
# 78702                     63.12                            158
# 78703                     30.99                            142
# 78704                    108.00                            158
# 78705                     59.40                            142
# 78712                       NaN                              1
# 78717                      8.04                             33
# 78719                      2.64                             33
# 78721                    154.00                            142
# 78722                     25.91                            142
# 78723                     35.45                             50
# 78724                     19.00                              5
# 78725                     18.16                              6
# 78726                      2.00                             74
# 78727                     16.14                             50
# 78728                     95.00                             50
# 78729                     26.00                            158
# 78730                     74.00                             74
# 78731                     30.83                             74
# 78732                     12.73                             50
# 78733                      9.95                             74
# 78734                     77.33                             74
# 78735                      4.73                            158
# 78736                     27.93                             74
# 78737                     45.00                             74
# 78738                     15.78                             74
# 78739                     81.43                              8
# 78741                     35.00                            142
# 78742                      2.05                              6
# 78744                     25.45                            158
# 78745                     78.95                            158
# 78746                     13.95                            142
# 78747                      5.29                             50
# 78748                     45.00                             74
# 78749                     28.80                             19
# 78750                      9.65                             50
# 78751                     88.00                            158
# 78752                     48.84                             29
# 78753                    250.00                             15
# 78754                     98.00                            158
# 78756                     19.06                            158
# 78757                     35.25                             21
# 78758                     41.15                            142
# 78759                     17.64                            142
#
#               availability_365
#                           amax
# neighbourhood
# 78701                      365
# 78702                      365
# 78703                      365
# 78704                      365
# 78705                      365
# 78712                        0
# 78717                      365
# 78719                      319
# 78721                      360
# 78722                      365
# 78723                      365
# 78724                      365
# 78725                      365
# 78726                      365
# 78727                      364
# 78728                      365
# 78729                      365
# 78730                      354
# 78731                      365
# 78732                      358
# 78733                      360
# 78734                      359
# 78735                      365
# 78736                      355
# 78737                      365
# 78738                      349
# 78739                      338
# 78741                      365
# 78742                       87
# 78744                      365
# 78745                      365
# 78746                      365
# 78747                      363
# 78748                      365
# 78749                      365
# 78750                      359
# 78751                      365
# 78752                      365
# 78753                      365
# 78754                      365
# 78756                      365
# 78757                      365
# 78758                      365
# 78759                      365

# %% [markdown]
# #### Display the count of listings in each neighbourhood zip code

# %%
airbnb.groupby('neighbourhood')['calculated_host_listings_count'].count().sort_values(ascending = False)
# Out:
# neighbourhood
# 78704    1818
# 78702    1316
# 78701     733
# 78741     674
# 78745     511
# 78703     508
# 78705     495
# 78751     460
# 78723     330
# 78746     248
# 78758     244
# 78734     223
# 78721     213
# 78757     203
# 78744     182
# 78722     177
# 78752     146
# 78748     143
# 78756     141
# 78731     123
# 78753     113
# 78754     109
# 78737     107
# 78759     102
# 78749      99
# 78729      98
# 78727      87
# 78735      83
# 78724      78
# 78733      67
# 78732      63
# 78728      62
# 78717      58
# 78747      54
# 78736      52
# 78738      51
# 78725      44
# 78750      40
# 78730      38
# 78739      29
# 78726      12
# 78742       8
# 78719       7
# 78712       1
# Name: calculated_host_listings_count, dtype: int64

# %% [markdown]
# #### Rename the _neighbourhood_ column to _zip_code_

# %%
airbnb.rename(columns = {'neighbourhood' : 'zip code'}, inplace = True)

# %%
airbnb.head(2)
# Out:
#      id                                               name  host_id host_name  \
# 0  2265   Zen-East in the Heart of Austin (monthly rental)     2466     Paddy
# 1  5245  Eco friendly, Colorful, Clean, Cozy monthly share     2466     Paddy
#
#    neighbourhood_group  zip code  latitude  longitude        room_type  price  \
# 0                  NaN     78702  30.27752  -97.71377  Entire home/apt    200
# 1                  NaN     78702  30.27614  -97.71320     Private room    114
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               7                 26  2021-07-02               0.38
# 1              30                  9  2017-02-24               0.22
#
#    calculated_host_listings_count  availability_365
# 0                               3                51
# 1                               3                 0

# %% [markdown]
# #### How many rows have a listing price < $500?

# %%
airbnb[airbnb['price'] < 500]
# Out:
#              id                                               name    host_id  \
# 0          2265   Zen-East in the Heart of Austin (monthly rental)       2466
# 1          5245  Eco friendly, Colorful, Clean, Cozy monthly share       2466
# 2          5456          Walk to 6th, Rainey St and Convention Ctr       8028
# 3          5769                                     NW Austin Room       8186
# 4          6413                      Gem of a Studio near Downtown      13879
# ...         ...                                                ...        ...
# 10345  50899252        Stay in a place of your own | 1BR in Austin  359036978
# 10346  50899636           Brilliant apartment home | 1BR in Austin  359036978
# 10347  50899637           Brilliant apartment home | 1BR in Austin  359036978
# 10348  50901766       Mid-Century on a corner lot with fenced yard      80406
# 10349  50903601   Poolside Fun close to Downtown Sleeps 8 w/6 beds    4912146
#
#        host_name  neighbourhood_group  neighbourhood   latitude  longitude  \
# 0          Paddy                  NaN          78702  30.277520 -97.713770
# 1          Paddy                  NaN          78702  30.276140 -97.713200
# 2         Sylvia                  NaN          78702  30.260570 -97.734410
# 3      Elizabeth                  NaN          78729  30.456970 -97.784220
# 4           Todd                  NaN          78704  30.248850 -97.735870
# ...          ...                  ...            ...        ...        ...
# 10345     Shelby                  NaN          78745  30.181934 -97.777781
# 10346     Shelby                  NaN          78729  30.447745 -97.783717
# 10347     Shelby                  NaN          78729  30.448854 -97.784034
# 10348       Dani                  NaN          78704  30.241941 -97.742844
# 10349     Deacon                  NaN          78705  30.290629 -97.750309
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt    200               7                 26  2021-07-02
# 1         Private room    114              30                  9  2017-02-24
# 2      Entire home/apt    126               2                560  2021-06-21
# 3         Private room     39               1                264  2021-07-03
# 4      Entire home/apt    104              30                117  2021-04-02
# ...                ...    ...             ...                ...         ...
# 10345  Entire home/apt    117              30                  0         NaN
# 10346  Entire home/apt    112              30                  0         NaN
# 10347  Entire home/apt    119              30                  0         NaN
# 10348  Entire home/apt    199               7                  0         NaN
# 10349  Entire home/apt    202               2                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 0                   0.38                               3                51
# 1                   0.22                               3                 0
# 2                  27.27                               1               329
# 3                   6.42                               1                30
# 4                   1.31                               1                 0
# ...                  ...                             ...               ...
# 10345                NaN                             158               365
# 10346                NaN                             158               365
# 10347                NaN                             158               365
# 10348                NaN                              12                63
# 10349                NaN                              20                11
#
# [9114 rows x 16 columns]

# %%
airbnb.loc[airbnb['price'] < 500].count()
# Out:
# id                                9114
# name                              9114
# host_id                           9114
# host_name                         9099
# neighbourhood_group                  0
# neighbourhood                     9114
# latitude                          9114
# longitude                         9114
# room_type                         9114
# price                             9114
# minimum_nights                    9114
# number_of_reviews                 9114
# last_review                       7179
# reviews_per_month                 7179
# calculated_host_listings_count    9114
# availability_365                  9114
# dtype: int64

# %%
airbnb.loc[airbnb['price'] < 500]['price'].count()
# Out:
# 9114

# %%
airbnb.loc[airbnb['price'] < 500].shape[0]
# Out:
# 9114

# %% [markdown]
# #### Create a new column called `listing_type`. For each row that has a room type of _Hotel room_, fill this new column with the value _hotel_. If the room type is **not** a hotel room, fill this new column with the value _home_.
# ##### Hint: We covered this earlier in the intro pandas section. You're welcome to use the internet as well to help!

# %% [markdown]
# ___

# %% [markdown]
# <div id="conapp"></div>
# <h2>Combine DataFrames with pd.concat()</h2>

# %% [markdown]
# ## Concatenate
#
# *Concatenate* means to sticks DataFrames together -  either on top of each other, or next to each other.
#
# First, let's create two DataFrames for hypothetical soccer data, both with standings data for different teams.

# %%
standings1 = pd.DataFrame(
    [['usa', 3, 4, 1], 
    ['canada', 7, 2, 0], 
    ['spain', 4, 5, 2], 
    ['nigeria', 4, 3, 3], 
    ['argentina', 5, 2, 1]], 
    columns=['team', 'wins', 'losses', 'ties']
)
standings1.head()
# Out:
#         team  wins  losses  ties
# 0        usa     3       4     1
# 1     canada     7       2     0
# 2      spain     4       5     2
# 3    nigeria     4       3     3
# 4  argentina     5       2     1

# %%
standings2 = pd.DataFrame(
    [['jamaica', 13, 14, 11], 
    ['italy', 17, 12, 10], 
    ['paraquay', 14, 15, 12], 
    ['burkina faso', 14, 13, 13], 
    ['japan', 15, 2, 11]], 
    columns=['team', 'wins', 'losses', 'ties']
)
standings2.head()
# Out:
#            team  wins  losses  ties
# 0       jamaica    13      14    11
# 1         italy    17      12    10
# 2      paraquay    14      15    12
# 3  burkina faso    14      13    13
# 4         japan    15       2    11

# %% [markdown]
# #### Stick the dataframes on top of each other using `concat`.

# %%
pd.concat([standings1, standings2])
# Out:
#            team  wins  losses  ties
# 0           usa     3       4     1
# 1        canada     7       2     0
# 2         spain     4       5     2
# 3       nigeria     4       3     3
# 4     argentina     5       2     1
# 0       jamaica    13      14    11
# 1         italy    17      12    10
# 2      paraquay    14      15    12
# 3  burkina faso    14      13    13
# 4         japan    15       2    11

# %% [markdown]
# #### Check out the index. How can we fix that?

# %%
pd.concat([standings1, standings2], ignore_index = True)
# Out:
#            team  wins  losses  ties
# 0           usa     3       4     1
# 1        canada     7       2     0
# 2         spain     4       5     2
# 3       nigeria     4       3     3
# 4     argentina     5       2     1
# 5       jamaica    13      14    11
# 6         italy    17      12    10
# 7      paraquay    14      15    12
# 8  burkina faso    14      13    13
# 9         japan    15       2    11

# %%
pd.concat([standings1, standings2]).reset_index(drop = True)
# Out:
#            team  wins  losses  ties
# 0           usa     3       4     1
# 1        canada     7       2     0
# 2         spain     4       5     2
# 3       nigeria     4       3     3
# 4     argentina     5       2     1
# 5       jamaica    13      14    11
# 6         italy    17      12    10
# 7      paraquay    14      15    12
# 8  burkina faso    14      13    13
# 9         japan    15       2    11

# %%
standings3 = pd.concat([standings1, standings2]).reset_index(drop = True)

# %%
standings3
# Out:
#            team  wins  losses  ties
# 0           usa     3       4     1
# 1        canada     7       2     0
# 2         spain     4       5     2
# 3       nigeria     4       3     3
# 4     argentina     5       2     1
# 5       jamaica    13      14    11
# 6         italy    17      12    10
# 7      paraquay    14      15    12
# 8  burkina faso    14      13    13
# 9         japan    15       2    11

# %% [markdown]
# #### Combine 3 DataFrames

# %%
pd.concat([standings1, standings2, standings3], ignore_index = True)
# Out:
#             team  wins  losses  ties
# 0            usa     3       4     1
# 1         canada     7       2     0
# 2          spain     4       5     2
# 3        nigeria     4       3     3
# 4      argentina     5       2     1
# 5        jamaica    13      14    11
# 6          italy    17      12    10
# 7       paraquay    14      15    12
# 8   burkina faso    14      13    13
# 9          japan    15       2    11
# 10           usa     3       4     1
# 11        canada     7       2     0
# 12         spain     4       5     2
# 13       nigeria     4       3     3
# 14     argentina     5       2     1
# 15       jamaica    13      14    11
# 16         italy    17      12    10
# 17      paraquay    14      15    12
# 18  burkina faso    14      13    13
# 19         japan    15       2    11

# %% [markdown]
# #### Side-by-side
# Stick the DataFrames next to each other.

# %%
pd.concat([standings1, standings2], axis = 1)
# Out:
#         team  wins  losses  ties          team  wins  losses  ties
# 0        usa     3       4     1       jamaica    13      14    11
# 1     canada     7       2     0         italy    17      12    10
# 2      spain     4       5     2      paraquay    14      15    12
# 3    nigeria     4       3     3  burkina faso    14      13    13
# 4  argentina     5       2     1         japan    15       2    11

# %% [markdown]
# ___
# ## Merging
#
# ### Merge DataFrames with `pd.merge()`

# %% [markdown]
# <div id="merge"></div>
#
# ### Inner join:
#
# Only rows that match on the specified columns in both tables are kept.
#
# ### Left join:
# All rows are kept from the left table. Only rows that match on the specified columns in the right table are kept. There may be NaNs.
#
# ### Outer join:
# All rows are kept. There may be NaNs.
#
#
# ## In all cases, all the columns stick around
#
# ![joins venn diagrams](./images/joins.png) [Image source](https://www.howtoautomate.in.th/wp-content/uploads/2017/09/2017-09-23-12_38_26-SQL-Join-Types-%E2%80%94-SQL-Joins-Explained.png)
#
#
# `merge` can effectively do everything that `join` can do.
#
# Note that `merge` is <i>both</i> a DataFrame method as well as a top level pandas function. Below, we'll be using the pandas function, `pd.merge()`.

# %% [markdown]
# #### Let's make another DataFrame
#
# Let's add goals information for some of those teams above

# %%
goals = pd.DataFrame(
    [['usa', 10, 14,], 
    ['canada', 15, 3], 
    ['italy', 8, 5], 
    ['japan', 14, 13], 
    ['argentina', 19, 12]], 
    columns=['team', 'goals_for', 'goals_against']
)
goals
# Out:
#         team  goals_for  goals_against
# 0        usa         10             14
# 1     canada         15              3
# 2      italy          8              5
# 3      japan         14             13
# 4  argentina         19             12

# %%
standings1
# Out:
#         team  wins  losses  ties
# 0        usa     3       4     1
# 1     canada     7       2     0
# 2      spain     4       5     2
# 3    nigeria     4       3     3
# 4  argentina     5       2     1

# %%
standings2
# Out:
#            team  wins  losses  ties
# 0       jamaica    13      14    11
# 1         italy    17      12    10
# 2      paraquay    14      15    12
# 3  burkina faso    14      13    13
# 4         japan    15       2    11

# %% [markdown]
# ### The default merge type is `inner`. ☝️

# %%
pd.merge(goals, standings1)
# Out:
#         team  goals_for  goals_against  wins  losses  ties
# 0        usa         10             14     3       4     1
# 1     canada         15              3     7       2     0
# 2  argentina         19             12     5       2     1

# %%
pd.merge(goals, standings1, how = 'left')
# Out:
#         team  goals_for  goals_against  wins  losses  ties
# 0        usa         10             14   3.0     4.0   1.0
# 1     canada         15              3   7.0     2.0   0.0
# 2      italy          8              5   NaN     NaN   NaN
# 3      japan         14             13   NaN     NaN   NaN
# 4  argentina         19             12   5.0     2.0   1.0

# %%
pd.merge(left = goals, right = standings1, how = 'right')
# Out:
#         team  goals_for  goals_against  wins  losses  ties
# 0        usa       10.0           14.0     3       4     1
# 1     canada       15.0            3.0     7       2     0
# 2      spain        NaN            NaN     4       5     2
# 3    nigeria        NaN            NaN     4       3     3
# 4  argentina       19.0           12.0     5       2     1

# %%
pd.merge(left = goals, right = standings1, how = 'outer')
# Out:
#         team  goals_for  goals_against  wins  losses  ties
# 0        usa       10.0           14.0   3.0     4.0   1.0
# 1     canada       15.0            3.0   7.0     2.0   0.0
# 2      italy        8.0            5.0   NaN     NaN   NaN
# 3      japan       14.0           13.0   NaN     NaN   NaN
# 4  argentina       19.0           12.0   5.0     2.0   1.0
# 5      spain        NaN            NaN   4.0     5.0   2.0
# 6    nigeria        NaN            NaN   4.0     3.0   3.0

# %%
pd.merge(goals, standings1, how = 'left', on = 'team')
# Out:
#         team  goals_for  goals_against  wins  losses  ties
# 0        usa         10             14   3.0     4.0   1.0
# 1     canada         15              3   7.0     2.0   0.0
# 2      italy          8              5   NaN     NaN   NaN
# 3      japan         14             13   NaN     NaN   NaN
# 4  argentina         19             12   5.0     2.0   1.0

# %%
goals.merge(standings2, how = 'inner', on = 'team')
# Out:
#     team  goals_for  goals_against  wins  losses  ties
# 0  italy          8              5    17      12    10
# 1  japan         14             13    15       2    11

# %%
goals.rename(columns = {'team' : 'country'}, inplace = True)

# %%
goals
# Out:
#      country  goals_for  goals_against
# 0        usa         10             14
# 1     canada         15              3
# 2      italy          8              5
# 3      japan         14             13
# 4  argentina         19             12

# %%
pd.merge(goals, standings1, how = 'left')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-41-78c7ade17c0d> in <module>
# ----> 1 pd.merge(goals, standings1, how = 'left')
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1281                 common_cols = left_cols.intersection(right_cols)
#    1282                 if len(common_cols) == 0:
# -> 1283                     raise MergeError(
#    1284                         "No common columns to perform merge on. "
#    1285                         f"Merge options: left_on={self.left_on}, "
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
pd.merge(goals, standings1, how = 'left', left_on = 'country', right_on = 'team')
# Out:
#      country  goals_for  goals_against       team  wins  losses  ties
# 0        usa         10             14        usa   3.0     4.0   1.0
# 1     canada         15              3     canada   7.0     2.0   0.0
# 2      italy          8              5        NaN   NaN     NaN   NaN
# 3      japan         14             13        NaN   NaN     NaN   NaN
# 4  argentina         19             12  argentina   5.0     2.0   1.0

# %%
pd.merge(goals, standings1, how = 'left', left_on = 'country', right_on = 'team').drop('team', axis = 1)
# Out:
#      country  goals_for  goals_against  wins  losses  ties
# 0        usa         10             14   3.0     4.0   1.0
# 1     canada         15              3   7.0     2.0   0.0
# 2      italy          8              5   NaN     NaN   NaN
# 3      japan         14             13   NaN     NaN   NaN
# 4  argentina         19             12   5.0     2.0   1.0

# %%
standings2
# Out:
#            team  wins  losses  ties
# 0       jamaica    13      14    11
# 1         italy    17      12    10
# 2      paraquay    14      15    12
# 3  burkina faso    14      13    13
# 4         japan    15       2    11

# %%
standings2['goals_for'] = [10, 8, 19, 20, 15]

# %%
standings2
# Out:
#            team  wins  losses  ties  goals_for
# 0       jamaica    13      14    11         10
# 1         italy    17      12    10          8
# 2      paraquay    14      15    12         19
# 3  burkina faso    14      13    13         20
# 4         japan    15       2    11         15

# %%
goals
# Out:
#      country  goals_for  goals_against
# 0        usa         10             14
# 1     canada         15              3
# 2      italy          8              5
# 3      japan         14             13
# 4  argentina         19             12

# %%
pd.merge(goals, standings2, how = 'inner', left_on = 'country', right_on = 'team')
# Out:
#   country  goals_for_x  goals_against   team  wins  losses  ties  goals_for_y
# 0   italy            8              5  italy    17      12    10            8
# 1   japan           14             13  japan    15       2    11           15

# %%
pd.merge(goals, standings2, how = 'inner', left_on = 'country', right_on = 'team', suffixes = ['', '_standings'])
# Out:
#   country  goals_for  goals_against   team  wins  losses  ties  \
# 0   italy          8              5  italy    17      12    10
# 1   japan         14             13  japan    15       2    11
#
#    goals_for_standings
# 0                    8
# 1                   15

# %% [markdown]
# <div id="exercise"></div>
# <h2>Table Joins</h2>
# <p align="right">
# <img src="http://lh6.ggpht.com/_XjcDyZkJqHg/TPaaRcaysbI/AAAAAAAAAFo/b1U3q-qbTjY/AdventureWorks%20Logo%5B5%5D.png?imgmax=800">
# </p>

# %%
p = pd.read_csv('./data/Production.Product.csv', sep='\t')
ps = pd.read_csv('./data/Production.ProductSubcategory.csv', sep='\t')
soh = pd.read_csv('./data/Sales.SalesOrderHeader.csv', sep='\t', nrows=1000)
sod = pd.read_csv('./data/Sales.SalesOrderDetail.csv', sep='\t', nrows=1000)

# %% [markdown]
# ### Change max number of columns you can see

# %%
p.head(2)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
# 1          2     Bearing Ball       BA-8327         0                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice  ...  \
# 0   NaN              1000           750           0.0        0.0  ...
# 1   NaN              1000           750           0.0        0.0  ...
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
# 1         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN              NaN
# 1  2008-04-30 00:00:00         NaN              NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000
#
# [2 rows x 25 columns]

# %%
pd.options.display.max_columns = None

# %%
p.head(2)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
# 1          2     Bearing Ball       BA-8327         0                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  \
# 0   NaN              1000           750           0.0        0.0  NaN
# 1   NaN              1000           750           0.0        0.0  NaN
#
#   SizeUnitMeasureCode WeightUnitMeasureCode  Weight  DaysToManufacture  \
# 0                 NaN                   NaN     NaN                  0
# 1                 NaN                   NaN     NaN                  0
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
# 1         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate  DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN               NaN
# 1  2008-04-30 00:00:00         NaN               NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000

# %%
pd.options.display.max_rows = 150

# %%
p.head(2)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
# 1          2     Bearing Ball       BA-8327         0                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  \
# 0   NaN              1000           750           0.0        0.0  NaN
# 1   NaN              1000           750           0.0        0.0  NaN
#
#   SizeUnitMeasureCode WeightUnitMeasureCode  Weight  DaysToManufacture  \
# 0                 NaN                   NaN     NaN                  0
# 1                 NaN                   NaN     NaN                  0
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
# 1         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate  DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN               NaN
# 1  2008-04-30 00:00:00         NaN               NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000

# %% [markdown]
# Check the DataFrame after changing _max_columns_

# %% [markdown]
# <div id="p_exercise"></div>
# <h3>Table Joins Exercise</h3>
#
# Here are the data dictionaries we'll be using for the following exercise:
#
# <ul>
#     <li><a href="https://www.sqldatadictionary.com/AdventureWorks2014/Production.Product.html">Production.Product</a></li>
#     <li><a href="https://www.sqldatadictionary.com/AdventureWorks2014/Production.ProductSubCategory.html">Production.ProductSubcategory</a></li>
#     <li><a href="https://www.sqldatadictionary.com/AdventureWorks2014/Sales.SalesOrderHeader.html">Sales.SalesOrderHeader</a></li>
#     <li><a href="https://www.sqldatadictionary.com/AdventureWorks2014/Sales.SalesOrderDetail.html">Sales.SalesOrderDetail</a></li>
# </ul>

# %% [markdown]
# ## Let's use an AdventureWorks Cycles Dataset
# <img align="right" src="http://lh6.ggpht.com/_XjcDyZkJqHg/TPaaRcaysbI/AAAAAAAAAFo/b1U3q-qbTjY/AdventureWorks%20Logo%5B5%5D.png?imgmax=800">
#
# Here's the Production.Product table [data dictionary](https://www.sqldatadictionary.com/AdventureWorks2014/Production.Product.html), which is a description of the fields (columns) in the table (the .csv file we will import below):<br>
# - **ProductID** - Primary key for Product records.
# - **Name** - Name of the product.
# - **ProductNumber** - Unique product identification number.
# - **MakeFlag** - 0 = Product is purchased, 1 = Product is manufactured in-house.
# - **FinishedGoodsFlag** - 0 = Product is not a salable item. 1 = Product is salable.
# - **Color** - Product color.
# - **SafetyStockLevel** - Minimum inventory quantity.
# - **ReorderPoint** - Inventory level that triggers a purchase order or work order.
# - **StandardCost** - Standard cost of the product.
# - **ListPrice** - Selling price.
# - **Size** - Product size.
# - **SizeUnitMeasureCode** - Unit of measure for the Size column.
# - **WeightUnitMeasureCode** - Unit of measure for the Weight column.
# - **DaysToManufacture** - Number of days required to manufacture the product.
# - **ProductLine** - R = Road, M = Mountain, T = Touring, S = Standard
# - **Class** - H = High, M = Medium, L = Low
# - **Style** - W = Womens, M = Mens, U = Universal
# - **ProductSubcategoryID** - Product is a member of this product subcategory. Foreign key to ProductSubCategory.ProductSubCategoryID.
# - **ProductModelID** - Product is a member of this product model. Foreign key to ProductModel.ProductModelID.
# - **SellStartDate** - Date the product was available for sale.
# - **SellEndDate** - Date the product was no longer available for sale.
# - **DiscontinuedDate** - Date the product was discontinued.
# - **rowguid** - ROWGUIDCOL number uniquely identifying the record. Used to support a merge replication sample.
# - **ModifiedDate** - Date and time the record was last updated.

# %% [markdown]
# <div id="ex_pp"></div>
# <h4>#1 Join Tables</h4>
#
# <ul>
#     <li>Using the <code>Production.Product.ProductID</code> and <code>Sales.SalesOrderDetail.ProductID</code> keys, join only the rows that match in both the <code>Production.Product</code> and <code>Sales.SalesOrderDetail</code> tables.</li>
# </ul>

# %%
p.head(2)
# Out:
#    ProductID             Name ProductNumber  MakeFlag  FinishedGoodsFlag  \
# 0          1  Adjustable Race       AR-5381         0                  0
# 1          2     Bearing Ball       BA-8327         0                  0
#
#   Color  SafetyStockLevel  ReorderPoint  StandardCost  ListPrice Size  \
# 0   NaN              1000           750           0.0        0.0  NaN
# 1   NaN              1000           750           0.0        0.0  NaN
#
#   SizeUnitMeasureCode WeightUnitMeasureCode  Weight  DaysToManufacture  \
# 0                 NaN                   NaN     NaN                  0
# 1                 NaN                   NaN     NaN                  0
#
#   ProductLine Class Style  ProductSubcategoryID  ProductModelID  \
# 0         NaN   NaN   NaN                   NaN             NaN
# 1         NaN   NaN   NaN                   NaN             NaN
#
#          SellStartDate SellEndDate  DiscontinuedDate  \
# 0  2008-04-30 00:00:00         NaN               NaN
# 1  2008-04-30 00:00:00         NaN               NaN
#
#                                   rowguid                   ModifiedDate
# 0  {694215B7-08F7-4C0D-ACB1-D734BA44C0C8}  2014-02-08 10:01:36.827000000
# 1  {58AE3C20-4F3A-4749-A7D4-D568806CC537}  2014-02-08 10:01:36.827000000

# %%
sod.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        776               1   2024.994                0.0   2024.994
# 1        777               1   2024.994                0.0   6074.982
#
#                                   rowguid         ModifiedDate
# 0  {B207C96D-D9E6-402B-8470-2CC176C42283}  2011-05-31 00:00:00
# 1  {7ABB600D-1E77-41BE-9FE5-B9142CFC08FA}  2011-05-31 00:00:00

# %%
pd.merge(p, sod, on = 'ProductID').head(3)
# Out:
#    ProductID                   Name ProductNumber  MakeFlag  \
# 0        707  Sport-100 Helmet, Red     HL-U509-R         0
# 1        707  Sport-100 Helmet, Red     HL-U509-R         0
# 2        707  Sport-100 Helmet, Red     HL-U509-R         0
#
#    FinishedGoodsFlag Color  SafetyStockLevel  ReorderPoint  StandardCost  \
# 0                  1   Red                 4             3       13.0863
# 1                  1   Red                 4             3       13.0863
# 2                  1   Red                 4             3       13.0863
#
#    ListPrice Size SizeUnitMeasureCode WeightUnitMeasureCode  Weight  \
# 0      34.99  NaN                 NaN                   NaN     NaN
# 1      34.99  NaN                 NaN                   NaN     NaN
# 2      34.99  NaN                 NaN                   NaN     NaN
#
#    DaysToManufacture ProductLine Class Style  ProductSubcategoryID  \
# 0                  0          S    NaN   NaN                  31.0
# 1                  0          S    NaN   NaN                  31.0
# 2                  0          S    NaN   NaN                  31.0
#
#    ProductModelID        SellStartDate SellEndDate  DiscontinuedDate  \
# 0            33.0  2011-05-31 00:00:00         NaN               NaN
# 1            33.0  2011-05-31 00:00:00         NaN               NaN
# 2            33.0  2011-05-31 00:00:00         NaN               NaN
#
#                                 rowguid_x                 ModifiedDate_x  \
# 0  {2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712}  2014-02-08 10:01:36.827000000
# 1  {2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712}  2014-02-08 10:01:36.827000000
# 2  {2E1EF41A-C08A-4FF6-8ADA-BDE58B64A712}  2014-02-08 10:01:36.827000000
#
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43665                  63          19F0-4638-8E         1
# 1         43668                  87          365D-4C9A-BE         2
# 2         43673                 139          260F-4DCF-A1         4
#
#    SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0               1    20.1865                0.0    20.1865
# 1               1    20.1865                0.0    40.3730
# 2               1    20.1865                0.0    80.7460
#
#                                 rowguid_y       ModifiedDate_y
# 0  {E4A00FC2-6EDA-40D7-AFB4-B6B4C5B3EDEE}  2011-05-31 00:00:00
# 1  {C0517F7A-8994-470A-BF62-D7D653972F2A}  2011-05-31 00:00:00
# 2  {AC5123F3-3719-4802-9A72-D9A90C721E60}  2011-05-31 00:00:00

# %%
len(pd.merge(p, sod, on = 'ProductID'))
# Out:
# 1000

# %% [markdown]
# <div id="ex_soh_sod"></div>
# <h4>#2 Join Sales Order Header and Sales Order Detail Tables</h4>
#
# <ul>
#     <li>Join the <code>Sales.SalesOrderHeader</code> and <code>Sales.SalesOrderDetail</code> tables with an inner join</li>
#     <li>Don't forget to use your data dictionary to find the columns to merge on!</li>
# </ul>
#     <li>**Advanced** : Can you think of a Pythonic way to find columns that are common to both dataframes?</li>
# </ul>

# %%
soh.head(2)
# Out:
#    SalesOrderID  RevisionNumber            OrderDate              DueDate  \
# 0         43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 1         43660               8  2011-05-31 00:00:00  2011-06-12 00:00:00
#
#               ShipDate  Status  OnlineOrderFlag SalesOrderNumber  \
# 0  2011-06-07 00:00:00       5                0          SO43659
# 1  2011-06-07 00:00:00       5                0          SO43660
#
#   PurchaseOrderNumber   AccountNumber  CustomerID  SalesPersonID  TerritoryID  \
# 0         PO522145787  10-4020-000676       29825          279.0            5
# 1       PO18850127500  10-4020-000117       29672          279.0            5
#
#    BillToAddressID  ShipToAddressID  ShipMethodID  CreditCardID  \
# 0              985              985             5       16281.0
# 1              921              921             5        5618.0
#
#   CreditCardApprovalCode  CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0          105041Vi84182             NaN  20565.6206  1971.5149  616.0984
# 1          115213Vi29411             NaN   1294.2529   124.2483   38.8276
#
#      TotalDue  Comment                                 rowguid  \
# 0  23153.2339      NaN  {79B65321-39CA-4115-9CBA-8FE0903E12E6}
# 1   1457.3288      NaN  {738DC42D-D03B-48A1-9822-F95A67EA7389}
#
#           ModifiedDate
# 0  2011-06-07 00:00:00
# 1  2011-06-07 00:00:00

# %%
sod.head(2)
# Out:
#    SalesOrderID  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0         43659                   1          4911-403C-98         1
# 1         43659                   2          4911-403C-98         3
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        776               1   2024.994                0.0   2024.994
# 1        777               1   2024.994                0.0   6074.982
#
#                                   rowguid         ModifiedDate
# 0  {B207C96D-D9E6-402B-8470-2CC176C42283}  2011-05-31 00:00:00
# 1  {7ABB600D-1E77-41BE-9FE5-B9142CFC08FA}  2011-05-31 00:00:00

# %%
pd.merge(soh, sod, on = 'SalesOrderID').head(3)
# Out:
#    SalesOrderID  RevisionNumber            OrderDate              DueDate  \
# 0         43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 1         43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 2         43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
#
#               ShipDate  Status  OnlineOrderFlag SalesOrderNumber  \
# 0  2011-06-07 00:00:00       5                0          SO43659
# 1  2011-06-07 00:00:00       5                0          SO43659
# 2  2011-06-07 00:00:00       5                0          SO43659
#
#   PurchaseOrderNumber   AccountNumber  CustomerID  SalesPersonID  TerritoryID  \
# 0         PO522145787  10-4020-000676       29825          279.0            5
# 1         PO522145787  10-4020-000676       29825          279.0            5
# 2         PO522145787  10-4020-000676       29825          279.0            5
#
#    BillToAddressID  ShipToAddressID  ShipMethodID  CreditCardID  \
# 0              985              985             5       16281.0
# 1              985              985             5       16281.0
# 2              985              985             5       16281.0
#
#   CreditCardApprovalCode  CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0          105041Vi84182             NaN  20565.6206  1971.5149  616.0984
# 1          105041Vi84182             NaN  20565.6206  1971.5149  616.0984
# 2          105041Vi84182             NaN  20565.6206  1971.5149  616.0984
#
#      TotalDue  Comment                               rowguid_x  \
# 0  23153.2339      NaN  {79B65321-39CA-4115-9CBA-8FE0903E12E6}
# 1  23153.2339      NaN  {79B65321-39CA-4115-9CBA-8FE0903E12E6}
# 2  23153.2339      NaN  {79B65321-39CA-4115-9CBA-8FE0903E12E6}
#
#         ModifiedDate_x  SalesOrderDetailID CarrierTrackingNumber  OrderQty  \
# 0  2011-06-07 00:00:00                   1          4911-403C-98         1
# 1  2011-06-07 00:00:00                   2          4911-403C-98         3
# 2  2011-06-07 00:00:00                   3          4911-403C-98         1
#
#    ProductID  SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0        776               1   2024.994                0.0   2024.994
# 1        777               1   2024.994                0.0   6074.982
# 2        778               1   2024.994                0.0   2024.994
#
#                                 rowguid_y       ModifiedDate_y
# 0  {B207C96D-D9E6-402B-8470-2CC176C42283}  2011-05-31 00:00:00
# 1  {7ABB600D-1E77-41BE-9FE5-B9142CFC08FA}  2011-05-31 00:00:00
# 2  {475CF8C6-49F6-486E-B0AD-AFC6A50CDD2F}  2011-05-31 00:00:00

# %%
pd.merge(soh, sod, on = 'SalesOrderID')
# Out:
#      SalesOrderID  RevisionNumber            OrderDate              DueDate  \
# 0           43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 1           43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 2           43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 3           43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 4           43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# ..            ...             ...                  ...                  ...
# 995         43892               8  2011-07-01 00:00:00  2011-07-13 00:00:00
# 996         43893               8  2011-07-01 00:00:00  2011-07-13 00:00:00
# 997         43894               8  2011-07-01 00:00:00  2011-07-13 00:00:00
# 998         43894               8  2011-07-01 00:00:00  2011-07-13 00:00:00
# 999         43894               8  2011-07-01 00:00:00  2011-07-13 00:00:00
#
#                 ShipDate  Status  OnlineOrderFlag SalesOrderNumber  \
# 0    2011-06-07 00:00:00       5                0          SO43659
# 1    2011-06-07 00:00:00       5                0          SO43659
# 2    2011-06-07 00:00:00       5                0          SO43659
# 3    2011-06-07 00:00:00       5                0          SO43659
# 4    2011-06-07 00:00:00       5                0          SO43659
# ..                   ...     ...              ...              ...
# 995  2011-07-08 00:00:00       5                0          SO43892
# 996  2011-07-08 00:00:00       5                0          SO43893
# 997  2011-07-08 00:00:00       5                0          SO43894
# 998  2011-07-08 00:00:00       5                0          SO43894
# 999  2011-07-08 00:00:00       5                0          SO43894
#
#     PurchaseOrderNumber   AccountNumber  CustomerID  SalesPersonID  \
# 0           PO522145787  10-4020-000676       29825          279.0
# 1           PO522145787  10-4020-000676       29825          279.0
# 2           PO522145787  10-4020-000676       29825          279.0
# 3           PO522145787  10-4020-000676       29825          279.0
# 4           PO522145787  10-4020-000676       29825          279.0
# ..                  ...             ...         ...            ...
# 995        PO2523117473  10-4020-000167       29716          281.0
# 996        PO2204129382  10-4020-000370       29905          282.0
# 997        PO2958194987  10-4020-000559       30004          280.0
# 998        PO2958194987  10-4020-000559       30004          280.0
# 999        PO2958194987  10-4020-000559       30004          280.0
#
#      TerritoryID  BillToAddressID  ShipToAddressID  ShipMethodID  \
# 0              5              985              985             5
# 1              5              985              985             5
# 2              5              985              985             5
# 3              5              985              985             5
# 4              5              985              985             5
# ..           ...              ...              ...           ...
# 995            4             1015             1015             5
# 996            6              505              505             5
# 997            1              892              892             5
# 998            1              892              892             5
# 999            1              892              892             5
#
#      CreditCardID CreditCardApprovalCode  CurrencyRateID    SubTotal  \
# 0         16281.0          105041Vi84182             NaN  20565.6206
# 1         16281.0          105041Vi84182             NaN  20565.6206
# 2         16281.0          105041Vi84182             NaN  20565.6206
# 3         16281.0          105041Vi84182             NaN  20565.6206
# 4         16281.0          105041Vi84182             NaN  20565.6206
# ..            ...                    ...             ...         ...
# 995       13468.0           26813Vi69778             NaN  16544.5461
# 996       18480.0          116815Vi96000           407.0    419.4589
# 997        4842.0           46884Vi25430             NaN  32492.6040
# 998        4842.0           46884Vi25430             NaN  32492.6040
# 999        4842.0           46884Vi25430             NaN  32492.6040
#
#         TaxAmt   Freight    TotalDue  Comment  \
# 0    1971.5149  616.0984  23153.2339      NaN
# 1    1971.5149  616.0984  23153.2339      NaN
# 2    1971.5149  616.0984  23153.2339      NaN
# 3    1971.5149  616.0984  23153.2339      NaN
# 4    1971.5149  616.0984  23153.2339      NaN
# ..         ...       ...         ...      ...
# 995  1587.1682  495.9901  18627.7044      NaN
# 996    40.2681   12.5838    472.3108      NaN
# 997  3118.7048  974.5952  36585.9040      NaN
# 998  3118.7048  974.5952  36585.9040      NaN
# 999  3118.7048  974.5952  36585.9040      NaN
#
#                                   rowguid_x       ModifiedDate_x  \
# 0    {79B65321-39CA-4115-9CBA-8FE0903E12E6}  2011-06-07 00:00:00
# 1    {79B65321-39CA-4115-9CBA-8FE0903E12E6}  2011-06-07 00:00:00
# 2    {79B65321-39CA-4115-9CBA-8FE0903E12E6}  2011-06-07 00:00:00
# 3    {79B65321-39CA-4115-9CBA-8FE0903E12E6}  2011-06-07 00:00:00
# 4    {79B65321-39CA-4115-9CBA-8FE0903E12E6}  2011-06-07 00:00:00
# ..                                      ...                  ...
# 995  {386511B7-D278-479C-90B9-687FF0E045BD}  2011-07-08 00:00:00
# 996  {F3AFB011-5243-435C-9895-A520A4FC972D}  2011-07-08 00:00:00
# 997  {BB847425-22C1-4432-BF39-88E9C7CEE13A}  2011-07-08 00:00:00
# 998  {BB847425-22C1-4432-BF39-88E9C7CEE13A}  2011-07-08 00:00:00
# 999  {BB847425-22C1-4432-BF39-88E9C7CEE13A}  2011-07-08 00:00:00
#
#      SalesOrderDetailID CarrierTrackingNumber  OrderQty  ProductID  \
# 0                     1          4911-403C-98         1        776
# 1                     2          4911-403C-98         3        777
# 2                     3          4911-403C-98         1        778
# 3                     4          4911-403C-98         1        771
# 4                     5          4911-403C-98         1        772
# ..                  ...                   ...       ...        ...
# 995                 996          0D3C-4E1F-9C         2        765
# 996                 997          7C5D-46AA-A7         1        770
# 997                 998          7DF2-4E54-B0         3        710
# 998                 999          7DF2-4E54-B0         2        777
# 999                1000          7DF2-4E54-B0         3        775
#
#      SpecialOfferID  UnitPrice  UnitPriceDiscount  LineTotal  \
# 0                 1  2024.9940                0.0  2024.9940
# 1                 1  2024.9940                0.0  6074.9820
# 2                 1  2024.9940                0.0  2024.9940
# 3                 1  2039.9940                0.0  2039.9940
# 4                 1  2039.9940                0.0  2039.9940
# ..              ...        ...                ...        ...
# 995               1   419.4589                0.0   838.9178
# 996               1   419.4589                0.0   419.4589
# 997               1     5.7000                0.0    17.1000
# 998               1  2024.9940                0.0  4049.9880
# 999               1  2024.9940                0.0  6074.9820
#
#                                   rowguid_y       ModifiedDate_y
# 0    {B207C96D-D9E6-402B-8470-2CC176C42283}  2011-05-31 00:00:00
# 1    {7ABB600D-1E77-41BE-9FE5-B9142CFC08FA}  2011-05-31 00:00:00
# 2    {475CF8C6-49F6-486E-B0AD-AFC6A50CDD2F}  2011-05-31 00:00:00
# 3    {04C4DE91-5815-45D6-8670-F462719FBCE3}  2011-05-31 00:00:00
# 4    {5A74C7D2-E641-438E-A7AC-37BF23280301}  2011-05-31 00:00:00
# ..                                      ...                  ...
# 995  {30EDDEA5-2C93-4F08-B66E-BFADB84AFF0E}  2011-07-01 00:00:00
# 996  {46A1DA27-B11D-4918-8308-4B7715C12FB5}  2011-07-01 00:00:00
# 997  {6005BBFE-CD7C-45FD-80F7-DBBADB10BFEC}  2011-07-01 00:00:00
# 998  {03FF934E-043F-4CE7-8F44-18BFEE7EDBB7}  2011-07-01 00:00:00
# 999  {1EBF5ABC-DDFF-4EE0-8C21-F3DE78477319}  2011-07-01 00:00:00
#
# [1000 rows x 36 columns]

# %%
soh.columns
# Out:
# Index(['SalesOrderID', 'RevisionNumber', 'OrderDate', 'DueDate', 'ShipDate',
#        'Status', 'OnlineOrderFlag', 'SalesOrderNumber', 'PurchaseOrderNumber',
#        'AccountNumber', 'CustomerID', 'SalesPersonID', 'TerritoryID',
#        'BillToAddressID', 'ShipToAddressID', 'ShipMethodID', 'CreditCardID',
#        'CreditCardApprovalCode', 'CurrencyRateID', 'SubTotal', 'TaxAmt',
#        'Freight', 'TotalDue', 'Comment', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
sod.columns
# Out:
# Index(['SalesOrderID', 'SalesOrderDetailID', 'CarrierTrackingNumber',
#        'OrderQty', 'ProductID', 'SpecialOfferID', 'UnitPrice',
#        'UnitPriceDiscount', 'LineTotal', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
soh.columns & sod.columns
# Out:
# <ipython-input-79-ea2082db8345>:1: FutureWarning: Index.__and__ operating as a set operation is deprecated, in the future this will be a logical operation matching Series.__and__.  Use index.intersection(other) instead
#   soh.columns & sod.columns
# Index(['SalesOrderID', 'rowguid', 'ModifiedDate'], dtype='object')

# %%
a = np.intersect1d(soh.columns, sod.columns)

print ("Common Columns:",a)
# Out:
# Common Columns: ['ModifiedDate' 'SalesOrderID' 'rowguid']

# %%
len(soh.columns)
# Out:
# 26

# %%
len(sod.columns)
# Out:
# 11

# %%
soh.columns.difference(sod.columns)
# Out:
# Index(['AccountNumber', 'BillToAddressID', 'Comment', 'CreditCardApprovalCode',
#        'CreditCardID', 'CurrencyRateID', 'CustomerID', 'DueDate', 'Freight',
#        'OnlineOrderFlag', 'OrderDate', 'PurchaseOrderNumber', 'RevisionNumber',
#        'SalesOrderNumber', 'SalesPersonID', 'ShipDate', 'ShipMethodID',
#        'ShipToAddressID', 'Status', 'SubTotal', 'TaxAmt', 'TerritoryID',
#        'TotalDue'],
#       dtype='object')

# %% [markdown]
# ___
# # Summary
#
# You've seen how to use pandas DataFrames to clean your data and extract information. These are skills we'll continue to build in the course. 😀

# %% [markdown]
# ### Check for Understanding
#
# - What does a left join do?
# - What's the pandas method for doing split-apply-combine operations?
# - How do you stack two DataFrames on top of each other?
